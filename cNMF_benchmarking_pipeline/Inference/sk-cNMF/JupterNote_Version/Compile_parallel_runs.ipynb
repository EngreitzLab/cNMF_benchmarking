# %%
import os
import shutil
from pathlib import Path

# %% [markdown]
# # combine parallel inferred cNMF component results into one run

# %%
def rename_and_move_files_NMF(file_name_input, file_name_output, source_folder, destination_folder, len = 10):

    # Create destination folder if it doesn't exist
    Path(destination_folder).mkdir(parents=True, exist_ok=True)
    
    processed_files = []
    
    # Process files for i 
    for i in range(len):
        source_filename = f"{file_name_input}_{i}.df.npz"
        source_path = os.path.join(source_folder, source_filename)
        
        # Check if source file exists
        if os.path.exists(source_path):
            
            # Create new filename
            new_filename = f"{file_name_output}_{i}.df.npz"
            destination_path = os.path.join(destination_folder, new_filename)
            
            try:
                # Copy and rename file to destination
                shutil.copy2(source_path, destination_path)
                print(f"Successfully processed: {source_filename} -> {new_filename}")
                processed_files.append((source_filename, new_filename))
                
            except Exception as e:
                print(f"Error processing {source_filename}: {e}")
        else:
            print(f"File not found: {source_filename}")
    
    return processed_files

def rename_all_NMF(file_name_input, file_name_output, source_folder, destination_folder, components = [30, 50, 60, 80, 100, 200, 250, 300]):

    for k in components:

        file_name_input_new = f"{file_name_input}_{k}.spectra.k_{k}.iter"
        file_name_output_new = f"{file_name_output}.spectra.k_{k}.iter"

        source_folder_new = f"{source_folder}_{k}/cnmf_tmp"

        rename_and_move_files_NMF(file_name_input_new, file_name_output_new, source_folder_new, destination_folder)

# %%
source_dir = "/oak/stanford/groups/engreitz/Users/ymo/NMF_re-inplementing/Results/torch-cNMF_evaluation/091625_100k_cells_10iter_torch_halsvar_batch_e7_par/091625_100k_cells_10iter_torch_halsvar_batch_e7_par"
dest_dir = "/oak/stanford/groups/engreitz/Users/ymo/NMF_re-inplementing/Results/torch-cNMF_evaluation/091625_100k_cells_10iter_torch_halsvar_batch_e7_par/091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all/cnmf_tmp"

file_name_input = "091625_100k_cells_10iter_torch_halsvar_batch_e7_par"
file_name_output =  "091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all"

rename_all_NMF(file_name_input,file_name_output,source_dir, dest_dir, components = [30, 50, 60, 80, 100, 200, 250, 300] )
# Out:
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_5.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_6.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_6.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_7.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_7.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_8.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_8.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_30.spectra.k_30.iter_9.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_30.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_5.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_6.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_6.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_7.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_7.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_8.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_8.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_50.spectra.k_50.iter_9.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_50.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_5.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_6.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_6.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_7.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_7.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_8.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_8.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_60.spectra.k_60.iter_9.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_60.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_5.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_6.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_6.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_7.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_7.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_8.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_8.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_80.spectra.k_80.iter_9.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_80.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_5.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_6.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_6.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_7.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_7.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_8.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_8.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_100.spectra.k_100.iter_9.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_100.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_200.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_200.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_200.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_200.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_200.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_200.iter_5.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_6.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_7.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_8.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_200.spectra.k_200.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_250.iter_0.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_1.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_2.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_3.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_4.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_5.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_6.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_7.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_8.df.npz
# File not found: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_250.spectra.k_250.iter_9.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_0.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_0.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_1.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_1.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_2.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_2.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_3.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_3.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_4.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_4.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_5.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_5.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_6.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_6.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_7.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_7.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_8.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_8.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_300.spectra.k_300.iter_9.df.npz -> 091625_100k_cells_10iter_torch_halsvar_batch_e7_par_all.spectra.k_300.iter_9.df.npz

# %% [markdown]
# # combine 2 different cNMF into one

# %%
def rename_and_move_files(k, file_name_input, file_name_output, source_dir, dest_dir, len = 10, second = False):
    
    # Create destination folder if it doesn't exist
    Path(dest_dir).mkdir(parents=True, exist_ok=True)
    
    processed_files = []
    
    # Process files for i 
    for i in range(len):

        source_file = f"{file_name_input}.spectra.k_{k}.iter_{i}.df.npz"
        source_path = os.path.join(source_dir, source_file )

        # Check if source file exists
        if os.path.exists(source_dir): 

            if second: 
                i = i + 10
            
            # Create new filename
            new_filename = f"{file_name_output}.spectra.k_{k}.iter_{i}.df.npz"
            destination_path = os.path.join(dest_dir, new_filename)
            
            try:
                # Copy and rename file to destination
                shutil.copy2(source_path, destination_path)
                print(f"Successfully processed: {source_file} -> {new_filename}")
                processed_files.append((source_file , new_filename))
                
            except Exception as e:
                print(f"Error processing {file_name_input}: {e}")
        else:
            print(f"File not found: {file_name_input}")
            print(source_path)
    
    return processed_files


def rename_all(file_name_input, file_name_output, source_dir, dest_dir, components = [30, 50, 60, 80, 100, 200, 250, 300], second = False):

    for k in components:

        data = rename_and_move_files(k, file_name_input, file_name_output, source_dir, dest_dir, second = second)

# %%
source_dir = "/oak/stanford/groups/engreitz/Users/ymo/NMF_re-inplementing/Results/torch-cNMF_evaluation/091625_100k_cells_10iter_torch_halsvar_online_e7/cnmf_tmp"
dest_dir = "/oak/stanford/groups/engreitz/Users/ymo/NMF_re-inplementing/Results/Consensus_across_methods/online_halsvar_cd_e7/cnmf_tmp"

file_name_input = "091625_100k_cells_10iter_torch_halsvar_online_e7"
file_name_output =  "online_halsvar_cd_e7"

rename_all(file_name_input,file_name_output, source_dir, dest_dir, components = [30, 50, 60, 80, 100, 200, 250, 300], second = True)
# Out:
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_30.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_30.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_50.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_50.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_60.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_60.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_80.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_80.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_100.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_100.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_200.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_200.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_250.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_250.iter_19.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_0.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_10.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_1.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_11.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_2.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_12.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_3.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_13.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_4.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_14.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_5.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_15.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_6.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_16.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_7.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_17.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_8.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_18.df.npz
# Successfully processed: 091625_100k_cells_10iter_torch_halsvar_online_e7.spectra.k_300.iter_9.df.npz -> online_halsvar_cd_e7.spectra.k_300.iter_19.df.npz
